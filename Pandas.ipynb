# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
city = ['Berlin', 'Erlangen', 'Zurich',' Hamburg', 'Munich']

# %%
city
# Out:
# ['Berlin', 'Erlangen', 'Zurich', ' Hamburg', 'Munich']

# %%
df = pd.DataFrame(city)

# %%
df
# Out:
#           0
# 0    Berlin
# 1  Erlangen
# 2    Zurich
# 3   Hamburg
# 4    Munich

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame(city, columns=['City In Europe'], index=['c1','c2','c3','c4','c5'])
df
# Out:
#    City In Europe
# c1         Berlin
# c2       Erlangen
# c3         Zurich
# c4        Hamburg
# c5         Munich

# %%
city2 = ['Dprtmud','Paris','Potsdam','NRW','Dortmund']
df2 = pd.DataFrame(zip(city,city2), columns=['city1','city2']) #add 2 list

# %%
df2
# Out:
#       city1     city2
# 0    Berlin   Dprtmud
# 1  Erlangen     Paris
# 2    Zurich   Potsdam
# 3   Hamburg       NRW
# 4    Munich  Dortmund

# %%
df2.shape
# Out:
# (5, 2)

# %%
#two-dimensional array list to table
city3 = [['Bavaria','Erlangen'],['NRW', 'Dortmund']]
df4 = pd.DataFrame(city3, columns=['State','City'])

# %%
df4
# Out:
#      State      City
# 0  Bavaria  Erlangen
# 1      NRW  Dortmund

# %%
#dictionary to dataFrame

# %%
dict1 = {
    'city1':city,
    'city2':city2
}

# %%
df5 = pd.DataFrame(dict1)
df5
# Out:
#       city1     city2
# 0    Berlin   Dprtmud
# 1  Erlangen     Paris
# 2    Zurich   Potsdam
# 3   Hamburg       NRW
# 4    Munich  Dortmund

# %%
#import Excel file
df = pd.read_csv('Screen Time Data.csv')

# %%
df
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 4       4  04/21/19     Sunday                  56                 35
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 11     11  04/28/19     Sunday                  85                 42
# ...

# %%
#print column
df.columns
# Out:
# Index(['index', 'Date', 'Week Day', 'Total Screen Time ', 'Social Networking',
#        'Reading and Reference', 'Other', 'Productivity', 'Health and Fitness',
#        'Entertainment', 'Creativity', 'Yoga'],
#       dtype='object')

# %%
#print values
df.values
# Out:
# array([[0, '04/17/19', 'Wednesday', 187, 89, 17, 41, 22, 0, 0, 0, 0],
#        [1, '04/18/19', 'Thursday', 123, 78, 17, 8, 9, 0, 0, 0, 0],
#        [2, '04/19/19', 'Friday', 112, 52, 40, 8, 4, 0, 3, 0, 0],
#        [3, '04/20/19', 'Saturday', 101, 69, 9, 38, 2, 0, 3, 0, 0],
#        [4, '04/21/19', 'Sunday', 56, 35, 2, 43, 3, 0, 1, 1, 0],
#        [5, '04/22/19', 'Monday', 189, 68, 0, 9, 3, 4, 0, 0, 0],
#        [6, '04/23/19', 'Tuesday', 158, 56, 18, 41, 12, 15, 0, 0, 0],
#        [7, '04/24/19', 'Wednesday', 135, 98, 3, 33, 16, 0, 0, 0, 0],
#        [8, '04/25/19', 'Thursday', 52, 25, 7, 3, 16, 0, 0, 0, 0],
#        [9, '04/26/19', 'Friday', 198, 76, 8, 29, 15, 0, 32, 0, 0],
#        [10, '04/27/19', 'Saturday', 116, 75, 10, 20, 5, 0, 0, 0, 0],
#        [11, '04/28/19', 'Sunday', 85, 42, 22, 4, 2, 0, 0, 0, 0],
#        [12, '04/29/19', 'Monday', 109, 46, 8, 13, 9, 15, 1, 0, 1],
#        [13, '04/30/19', 'Tuesday', 79, 40, 2, 9, 12, 0, 0, 0, 1],
# ...

# %%
#print row
df.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
#print specific column
df.Date
# Out:
# 0     04/17/19
# 1     04/18/19
# 2     04/19/19
# 3     04/20/19
# 4     04/21/19
# 5     04/22/19
# 6     04/23/19
# 7     04/24/19
# 8     04/25/19
# 9     04/26/19
# 10    04/27/19
# 11    04/28/19
# 12    04/29/19
# 13    04/30/19
# 14    05/01/19
# 15    05/02/19
# 16    05/03/19
# 17    05/04/19
# 18    05/05/19
# 19    05/06/19
# 20    05/07/19
# 21    05/08/19
# 22    05/09/19
# 23    05/10/19
# 24    05/11/19
# 25    05/12/19
# 26    05/13/19
# 27    05/14/19
# Name: Date, dtype: object

# %%
#print specific column if column name is more than one word
df['Social Networking']
# Out:
# 0      89
# 1      78
# 2      52
# 3      69
# 4      35
# 5      68
# 6      56
# 7      98
# 8      25
# 9      76
# 10     75
# 11     42
# 12     46
# 13     40
# 14     90
# 15     60
# 16     64
# 17     34
# 18    109
# 19     81
# 20     70
# 21     53
# 22     42
# 23     93
# 24     49
# 25     28
# 26     37
# 27     41
# Name: Social Networking, dtype: int64

# %%
#print the rows from top
df.head(3)
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
#
#    Entertainment  Creativity  Yoga
# 0              0           0     0
# 1              0           0     0
# 2              3           0     0

# %%
# Print the rows from the top of a specific column
df.Date.head(4)
# Out:
# 0    04/17/19
# 1    04/18/19
# 2    04/19/19
# 3    04/20/19
# Name: Date, dtype: object
